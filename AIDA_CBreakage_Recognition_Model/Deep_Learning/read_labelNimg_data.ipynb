# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("../Car_Breakage_Data/Breakage_img_sample(JSONandImg)/1.Root_data(img)/damage/0000002_as-0036229.jpg", cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
import json


with open('../Car_Breakage_Data/Breakage_img_sample(JSONandImg)/2.Labeling_data(JSON)/damage/0000002_as-0036229.json', 'r') as f:
    json_data = json.load(f)

print(json.dumps(json_data) )
print(json_data.)
# Out:
# {"info": {"name": "external", "date_created": "04/20/2022"}, "images": {"id": 1, "width": 800, "height": 600, "file_name": "0000002_as-0036229.jpg"}, "annotations": [{"id": 2, "image_id": 1, "category_id": "as-0036229", "segmentation": [[[[438, 504], [440, 443], [436, 419], [439, 415], [429, 382], [404, 351], [363, 304], [414, 351], [420, 333], [425, 316], [427, 312], [418, 296], [409, 280], [363, 229], [336, 206], [336, 162], [347, 159], [408, 209], [416, 216], [447, 224], [459, 233], [468, 229], [485, 222], [495, 219], [516, 216], [534, 216], [508, 237], [486, 259], [466, 277], [465, 289], [469, 345], [469, 371], [449, 348], [436, 336], [436, 369], [450, 404], [451, 423], [447, 485], [438, 504]]]], "area": 14977.0, "bbox": [336, 159, 198, 345], "damage": "Breakage", "part": null, "year": 2020, "color": "Black", "level": null, "repair": ["Rear bumper:coating,exchange"]}], "categories": {"id": "as-0036229", "supercategory_name": "Full-size car"}}

# %%
import os

label_dir = {
    "breakage1" : "../Car_Breakage_Data/Breakage_img_sample(JSONandImg)/2.Labeling_data(JSON)/damage/",
    "breakage2" : " ../Car_Breakage_Data/Breakage_img_sample(JSONandImg)/2.Labeling_data(JSON)/damage_part/",
    "sedan_gia" : "../Car_NumberNAge_Data/car_numberNage_sample(JSON&img)/labeling_data/car_type_data_Sample/sedan/GIA",
    "sedan_hyeondai" : "../Car_NumberNAge_Data/car_numberNage_sample(JSON&img)/labeling_data/car_type_data_Sample/sedan/Hyeondai",
    "suv_gia" : "../Car_NumberNAge_Data/car_numberNage_sample(JSON&img)/labeling_data/car_type_data_Sample/SUV/GIA",
    "suv_hyeondai" : "../Car_NumberNAge_Data/car_numberNage_sample(JSON&img)/labeling_data/car_type_data_Sample/SUV/Hyeondai",
    "number" : "../Car_NumberNAge_Data/car_numberNage_sample(JSON&img)/labeling_data/car_number(OCR)data_Sample"
}

image_dir = {
    "breakage1" : "../Car_Breakage_Data/Breakage_img_sample(JSONandImg)/2.Labeling_data(JSON)/damage/",
    "breakage2" : " ../Car_Breakage_Data/Breakage_img_sample(JSONandImg)/2.Labeling_data(JSON)/damage_part/",
    "sedan_gia" : "../Car_NumberNAge_Data/car_numberNage_sample(JSON&img)/labeling_data/car_type_data_Sample/sedan/GIA",
    "sedan_hyeondai" : "../Car_NumberNAge_Data/car_numberNage_sample(JSON&img)/labeling_data/car_type_data_Sample/sedan/Hyeondai",
    "suv_gia" : "../Car_NumberNAge_Data/car_numberNage_sample(JSON&img)/root_data(img)/car_type_data_Sample/SUV/GIA",
    "suv_hyeondai" : "../Car_NumberNAge_Data/car_numberNage_sample(JSON&img)/root_data(img)/car_type_data_Sample/SUV/Hyeondai",
    "number" : "../Car_NumberNAge_Data/car_numberNage_sample(JSON&img)/root_data(img)/car_number(OCR)data_Sample"
}

# JSON파일 불러오기
file_list = os.listdir(label_dir)
